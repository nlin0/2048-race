# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/ai_prac/MLP"
# !pip install -q "numpy" "gymnasium" "torch"
# Out:
# /content/drive/MyDrive/YEAR 4/ai_prac/MLP

# %%
import torch
print("cuda:", torch.cuda.is_available())
if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
# Out:
# cuda: True
# NVIDIA A100-SXM4-80GB

# %%
# !python -m race2048.train_dqn --load checkpoints/dqn_1.pt --legacy-corner-shaping --save checkpoints/dqn_1.pt --steps 200000

# %%
# !python -m race2048.train_dqn --device cuda --load checkpoints/dqn_2.pt --save checkpoints/dqn_2_1.pt --steps 600000 --metrics-csv runs/metrics.csv

# %%
# !python -m race2048.train_dqn --device cuda --load checkpoints/dqn_2.pt --save checkpoints/dqn_2_1.pt --steps 1000000 --metrics-csv runs/metrics.csv
# Out:
# Game2048Env: anchor_corner=bl legacy_corner_shaping=False edge_fill_bonus=0.05 max_log2_increase_bonus=0.12 danger_axis_penalty=0.04
# Loaded checkpoints/dqn_2.pt — resume env_steps=4600000, train_steps=4596985
# Note: replay buffer is not in the checkpoint; it refills from scratch (capacity 100000). Gradients use random subsets until buffer grows.
# Metrics CSV: /content/drive/MyDrive/YEAR 4/ai_prac/MLP/runs/metrics.csv
# env_step 4610000/5600000  eps 0.010  buffer 10000  grad 4606858  mean_loss_2000 1.1787  ep 29  46s
# episode 50  env_step 4616375/5600000  eps 0.010  last_50ep: win% 0.0  mean_return 852.76  mean_len 327.5  mean_max_tile 370  best_max_tile 1024  mean_loss_2000 1.2563  buffer 16375  77s
# env_step 4620000/5600000  eps 0.010  buffer 20000  grad 4616858  mean_loss_2000 1.2288  ep 60  94s
# env_step 4630000/5600000  eps 0.010  buffer 30000  grad 4626858  mean_loss_2000 1.2654  ep 90  143s
# ...
